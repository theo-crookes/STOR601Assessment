# %% [markdown]
# <h3> Examples Of How To Use The tcc Package

# %% [markdown]
# Note that this Jupyter notebook is to showcase how this package can be used before implementing it. If you would like to test out the code used in this notebook, see the R file in the GitHub repository titled 'Example'.

# %% [markdown]
# Before using the package:
#
# library(ggplot2)
#
# library(tcc)
#
# We need ggplot2 for the plot function and also need to call the tcc package so we can use its functions. We will show how the functions can be used on the following data set:

# %% [markdown]
# ![thumbnail_image.png](attachment:thumbnail_image.png)

# %% [markdown]
# Now we can run the jarvis_march function to find the convex hull of x:

# %% [markdown]
# ![thumbnail_image2.png](attachment:thumbnail_image2.png)

# %% [markdown]
# Now we can use the plothull function to produce a plot of the data and the hull surrounding it:

# %% [markdown]
# ![thumbnail_image3.png](attachment:thumbnail_image3.png)

# %% [markdown]
# ![jarvisplot.png](attachment:jarvisplot.png)

# %% [markdown]
# Now we can use the length_of_hull function to find the length of the hull:

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# Now we can use the in_hull function on a list of points y to see if any of them are in the convex hull:

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# Now we can use the maximumdist function and the maximumdist_pair function to find the greatest distance between any pair of points on the hull and the pair of points that are furthest away respectively:

# %% [markdown]
# ![3.png](attachment:3.png)
